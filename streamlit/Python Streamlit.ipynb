# %% [markdown]
# # Python Streamlit 사용법 - 프로토 타입 만들기
#
# https://zzsza.github.io/mlops/2021/02/07/python-streamlit-dashboard/

# %% [markdown]
# - 프로토타입은 다양한 방법으로 만들 수 있으며 대표적인 프로토타입 도구는 아래와 같다.
#
# 1) Jupyter Notebook : 많이들 쓰시죠?
# 2) Flask : 백엔드를 직접 구성 + 프론트엔드 작업도 진행이 가능한 프로토 타입 도구 -> 하지만, 웹 개발에 신경을 쓰는 시간이 많아지기에 다른 방법을 찾게 된다
# 3) Dash : 제일 기능이 풍부한 Python 대시보드 라이브러리.
# 4) Voila : Jupyter Notebook을 바로 시각화 가능함.
# 5) Streamlit : 이 페이지에서 다룰 패키지

# %% [markdown]
# 모두 사용해보신 zzsza님의 의견은 아래와 같음.
#
# - 정리한 다음에 꼭 직접 사용해보고 내용을 추가해보자

# %% [markdown]
# | |장점 |이슈 | 이럴 때 사용하는 것을 추천 |
# |---|---|---|---|
# |`Jupyter Notebook`| 데이터 분석가, 데이터 사이언티스트에게 친숙한 환경 ipywidget을 사용해 인터랙티브 가능| Notebook에 익숙하지 않은 분들이 사용하기에 부적절함 | Notebook에 익숙한 동료에게 전달하는 경우|
# |`Flask or FastAPI`| 필요한 부분을 직접 개발 가능 & API화해서 실제 서비스에 반영하기에 좋음 | 개발이 필요하기 때문에 개발 리소스가 필요함(백엔드, 프론트) | 프로토타입 이후에 서비스화까지 고려하고 있는 경우, 개발을 할 수 있는 경우 |
# |`Dash`| 파이썬의 대표적인 대시보드 솔루션 & 인터렉티브한 환경 제공 & 대시보드 라이브러리 중 기능이 많은 편| Jupyter Notebook 등에서 만든 것을 바로 사용하기 어렵고 약간의 개발 리소스가 필요함 | 개발 리소스를 투입할 수 있는 경우(단, Flask보단 상대적으로 덜 투입될 수 있음), 인터렉티브한 기능이 필요한 경우|
# |`Voila`| Jupyter Notebook을 바로 대시보드로 사용할 수 있음(ipywidget 사용 가능) | Jupyter Notebook위에서 진행되기 때문에 ipywidget을 넘어서는 인터랙티브함은 어려움| Notebook 파일을 빠르게 프로토타입으로 만들어야 하는 경우& Notebook이 익숙하지 않은 동료에게 전달하는 경우 |
# |`Streamlit`| 자주 사용하는 위젯 존재 & 기존에 만든 함수 재활용 가능 | 개발 리소스 약간 필요 | 만든 코드를 수정해서 테스트하고 싶은경우 (Dash보다 상대적으로 시간이 덜 소요|

# %% [markdown]
# ## Streamlit 소개
# ---
# - 가장 빠르게 데이터 어플리케이션을 만들 수 있는 방법
# - 장점
#     - 간단하게 파이썬 코드로 앱을 빌드할 수 있음.
#     - 인터랙티브한 기능 제공 (백엔드 개발이나 HTTP 요청 구현할 필요 없음).
#     - 다양한 예시 제공
#     - 커뮤니티에서 개발한 Component도 존재함
#     - Streamlit에서 배포할 수 있는 시스템 제공 (단, 신청 필요)
#     - 화면을 녹화할 수 있는 Record 기능도 제공함
#         - app을 빌드한 후, 오른쪽 ☰ 버튼을 클릭하면 Record a screencast를 확인할 수 있음
#
# 참고 가능한 링크 : https://github.com/MarcSkovMadsen/awesome-streamlit

# %% [markdown]
# ## 그러면 맛보기 시작!

# %% [markdown]
# - 같은 directory에 있는 sample_code.py로 가서 봅시다!

# %%
# !pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.7.0-py2.py3-none-any.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 9.8 MB/s
# Collecting base58
#   Downloading base58-2.1.1-py3-none-any.whl (5.6 kB)
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.7.1-py2.py3-none-any.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 67.2 MB/s
# Collecting toml
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting tzlocal
#   Downloading tzlocal-4.1-py3-none-any.whl (19 kB)
# Collecting astor
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Collecting importlib-metadata>=1.4
#   Downloading importlib_metadata-4.11.3-py3-none-any.whl (18 kB)
# Collecting blinker
#   Downloading blinker-1.4.tar.gz (111 kB)
#      |████████████████████████████████| 111 kB 43.9 MB/s
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tornado>=5.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from streamlit) (6.1)
# Requirement already satisfied: pandas>=0.21.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from streamlit) (1.3.4)
# Collecting click>=7.0
#   Downloading click-8.0.4-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 35.1 MB/s
# Collecting gitpython!=3.1.19
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 20.0 MB/s
# Requirement already satisfied: packaging in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from streamlit) (21.3)
# Requirement already satisfied: numpy in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from streamlit) (1.21.4)
# Collecting validators
#   Downloading validators-0.18.2-py3-none-any.whl (19 kB)
# Collecting pyarrow
#   Downloading pyarrow-7.0.0-cp39-cp39-macosx_11_0_arm64.whl (14.6 MB)
#      |████████████████████████████████| 14.6 MB 118.9 MB/s
# Collecting altair>=3.2.0
#   Downloading altair-4.2.0-py3-none-any.whl (812 kB)
#      |████████████████████████████████| 812 kB 30.3 MB/s
# Collecting pympler>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      |████████████████████████████████| 164 kB 67.4 MB/s
# Collecting cachetools>=4.0
#   Downloading cachetools-5.0.0-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: python-dateutil in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: requests in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from streamlit) (2.26.0)
# Collecting semver
#   Downloading semver-2.13.0-py2.py3-none-any.whl (12 kB)
# Collecting protobuf!=3.11,>=3.6.0
#   Downloading protobuf-3.19.4-py2.py3-none-any.whl (162 kB)
#      |████████████████████████████████| 162 kB 72.4 MB/s
# Requirement already satisfied: pillow>=6.2.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from streamlit) (8.4.0)
# Requirement already satisfied: attrs in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from streamlit) (21.2.0)
# Collecting toolz
#   Downloading toolz-0.11.2-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 34.5 MB/s
# Collecting jsonschema>=3.0
#   Downloading jsonschema-4.4.0-py3-none-any.whl (72 kB)
#      |████████████████████████████████| 72 kB 13.6 MB/s
# Collecting jinja2
#   Using cached Jinja2-3.0.3-py3-none-any.whl (133 kB)
# Requirement already satisfied: entrypoints in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from altair>=3.2.0->streamlit) (0.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 18.6 MB/s
# Collecting zipp>=0.5
#   Downloading zipp-3.7.0-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: pytz>=2017.3 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from pandas>=0.21.0->streamlit) (2021.3)
# Requirement already satisfied: ipykernel>=5.1.2 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from pydeck>=0.1.dev5->streamlit) (6.5.0)
# Requirement already satisfied: traitlets>=4.3.2 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from pydeck>=0.1.dev5->streamlit) (5.1.1)
# Collecting ipywidgets>=7.0.0
#   Using cached ipywidgets-7.6.5-py2.py3-none-any.whl (121 kB)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from python-dateutil->streamlit) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from packaging->streamlit) (3.0.6)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from requests->streamlit) (3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from requests->streamlit) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from requests->streamlit) (2.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from requests->streamlit) (1.26.7)
# Collecting pytz-deprecation-shim
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: decorator>=3.4.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from validators->streamlit) (5.1.0)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: jupyter-client<8.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (7.0.6)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (1.5.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.1.3)
# Requirement already satisfied: ipython<8.0,>=7.23.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (7.29.0)
# Requirement already satisfied: appnope in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.1.2)
# Collecting widgetsnbextension~=3.5.0
#   Using cached widgetsnbextension-3.5.2-py2.py3-none-any.whl (1.6 MB)
# Collecting jupyterlab-widgets>=1.0.0
#   Using cached jupyterlab_widgets-1.0.2-py3-none-any.whl (243 kB)
# Collecting nbformat>=4.2.0
#   Downloading nbformat-5.2.0-py3-none-any.whl (74 kB)
#      |████████████████████████████████| 74 kB 21.4 MB/s
# Requirement already satisfied: ipython-genutils~=0.2.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.0-cp39-cp39-macosx_10_9_universal2.whl (17 kB)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Downloading pyrsistent-0.18.1-cp39-cp39-macosx_10_9_universal2.whl (81 kB)
#      |████████████████████████████████| 81 kB 35.0 MB/s
# Collecting tzdata
#   Downloading tzdata-2021.5-py2.py3-none-any.whl (339 kB)
#      |████████████████████████████████| 339 kB 29.7 MB/s
# Requirement already satisfied: setuptools>=18.5 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (58.2.0)
# Requirement already satisfied: pygments in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (2.10.0)
# Requirement already satisfied: pickleshare in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.7.5)
# Requirement already satisfied: backcall in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (3.0.22)
# Requirement already satisfied: jedi>=0.16 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.18.1)
# Requirement already satisfied: pyzmq>=13 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (22.3.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (1.5.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (4.9.1)
# Collecting notebook>=4.4.1
#   Downloading notebook-6.4.8-py3-none-any.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 113.3 MB/s
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from jedi>=0.16->ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.8.2)
# Collecting terminado>=0.8.3
#   Downloading terminado-0.13.3-py3-none-any.whl (14 kB)
# Collecting prometheus-client
#   Downloading prometheus_client-0.13.1-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 44.0 MB/s
# Collecting nbconvert
#   Downloading nbconvert-6.4.4-py3-none-any.whl (561 kB)
#      |████████████████████████████████| 561 kB 55.9 MB/s
# Collecting argon2-cffi
#   Downloading argon2_cffi-21.3.0-py3-none-any.whl (14 kB)
# Collecting Send2Trash>=1.8.0
#   Using cached Send2Trash-1.8.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from pexpect>4.3->ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.5)
# Collecting argon2-cffi-bindings
#   Downloading argon2_cffi_bindings-21.2.0-cp38-abi3-macosx_10_9_universal2.whl (53 kB)
#      |████████████████████████████████| 53 kB 21.0 MB/s
# Collecting pandocfilters>=1.4.1
#   Using cached pandocfilters-1.5.0-py2.py3-none-any.whl (8.7 kB)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.10.0-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 42.5 MB/s
# Collecting mistune<2,>=0.8.1
#   Using cached mistune-0.8.4-py2.py3-none-any.whl (16 kB)
# Collecting bleach
#   Using cached bleach-4.1.0-py2.py3-none-any.whl (157 kB)
# Collecting jupyterlab-pygments
#   Using cached jupyterlab_pygments-0.1.2-py2.py3-none-any.whl (4.6 kB)
# Collecting defusedxml
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting nbclient<0.6.0,>=0.5.0
#   Downloading nbclient-0.5.13-py3-none-any.whl (70 kB)
#      |████████████████████████████████| 70 kB 39.1 MB/s
# Collecting testpath
#   Downloading testpath-0.6.0-py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 17.1 MB/s
# Requirement already satisfied: cffi>=1.0.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.14.6)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.1-py3-none-any.whl (37 kB)
# Collecting webencodings
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: pycparser in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (2.20)
# Building wheels for collected packages: blinker
#   Building wheel for blinker (setup.py) ... done
#   Created wheel for blinker: filename=blinker-1.4-py3-none-any.whl size=13478 sha256=67192a7ebd19c8009cb0952c8bf71f08053520d951e32c795def769affb47384
#   Stored in directory: /Users/sunkeun/Library/Caches/pip/wheels/50/93/f8/4f0a42a03a06626d675f13907b6982ad5ecff383530af5a900
# Successfully built blinker
# Installing collected packages: pyrsistent, jsonschema, webencodings, soupsieve, nbformat, MarkupSafe, testpath, pandocfilters, nbclient, mistune, jupyterlab-pygments, jinja2, defusedxml, bleach, beautifulsoup4, argon2-cffi-bindings, terminado, Send2Trash, prometheus-client, nbconvert, argon2-cffi, notebook, widgetsnbextension, tzdata, smmap, jupyterlab-widgets, zipp, toolz, pytz-deprecation-shim, ipywidgets, gitdb, validators, tzlocal, toml, semver, pympler, pydeck, pyarrow, protobuf, importlib-metadata, gitpython, click, cachetools, blinker, base58, astor, altair, streamlit
# Successfully installed MarkupSafe-2.1.0 Send2Trash-1.8.0 altair-4.2.0 argon2-cffi-21.3.0 argon2-cffi-bindings-21.2.0 astor-0.8.1 base58-2.1.1 beautifulsoup4-4.10.0 bleach-4.1.0 blinker-1.4 cachetools-5.0.0 click-8.0.4 defusedxml-0.7.1 gitdb-4.0.9 gitpython-3.1.27 importlib-metadata-4.11.3 ipywidgets-7.6.5 jinja2-3.0.3 jsonschema-4.4.0 jupyterlab-pygments-0.1.2 jupyterlab-widgets-1.0.2 mistune-0.8.4 nbclient-0.5.13 nbconvert-6.4.4 nbformat-5.2.0 notebook-6.4.8 pandocfilters-1.5.0 prometheus-client-0.13.1 protobuf-3.19.4 pyarrow-7.0.0 pydeck-0.7.1 pympler-1.0.1 pyrsistent-0.18.1 pytz-deprecation-shim-0.1.0.post0 semver-2.13.0 smmap-5.0.0 soupsieve-2.3.1 streamlit-1.7.0 terminado-0.13.3 testpath-0.6.0 toml-0.10.2 toolz-0.11.2 tzdata-2021.5 tzlocal-4.1 validators-0.18.2 webencodings-0.5.1 widgetsnbextension-3.5.2 zipp-3.7.0

# %% [markdown]
# ## Streamlit API 소개
#
# - 제목 설정하기 (st.title)
# - 캐싱하기
# - 위젯 만들기
#     - 버튼 만들기
#     - 체크 박스 만들기
#     - 라디오 버튼 만들기
#     - 선택 박스 만들기
#     - 다중 선택 박스 만들기
#     - 슬라이더 만들기
#
# - 데이터 입력
# - 데이터 출력
# - 차트 출력
# - Progress, Status 메세지
# - 각종 컨텐츠 출력
# - 사이드바, 레이아웃

# %% [markdown]
# ### 제목 설정하기
#
# - 타이틀
#
# `st.title("Title")`
#
# - 헤더
#
# `st.header("Header")`
#
# - 서브헤더
#
# `st.subheader("subheader")`
#
#
# ### 텍스트 작성하기
#
# `st.write("Write Someting")`

# %% [markdown]
# ### 캐싱하기
#
# - 특정 버튼을 누를 때, 데이터를 불러오고 싶은 경우가 존재함
#     - 데이터가 많은 경우에, 반복적으로 데이터를 불러오는 것보다, 중간에 캐싱을 하면 속도도 개선되고 좋은 UX 경험을 가질 수 있음
#
# - Streamlit에선 `st.cache` 데코레이터를 사용하면 캐싱을 진행함
#
#     - 함수 이름 확인
#     - 함수를 구성하는 코드 확인
#     - 함수 호출시 사용하는 매개변수
#     - 위 3개를 확인하며 로컬에 저장해두고(=캐싱) 다시 호출시 캐싱을 사용할 수 있다면 그대로 사용함
#
# 더 자세한 내용은 [공식문서](https://docs.streamlit.io/library/advanced-features/caching)을 확인할 것
#
#
# ### 위젯 만들기
#
# - 버튼 만들기
#
# `if st.button("click button"):
#     st.write("Data Loading..")
#     # 데이터 로딩 함수는 여기에!`
#
#
# - 체크 박스 만들기
#
# `checkbox_btn  = st.checkbox('Checkbox Button')`

# %%
if checkbox_btn:
    st.write("Great!")

# %% [markdown]
# - 만약, Default로 체크하고 싶다면 `st.checkbox(value=True)`를 주면 됨

# %%
checkbox_btn2 = st.checkbox('Checkbox Button2',value= True)

if checkbox_btn2:
    st.write("Button2")
